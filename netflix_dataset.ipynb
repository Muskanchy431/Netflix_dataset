# %%
print("📚 What the Project is About:")
print("This project analyzes the Netflix Movies dataset to explore trends in movie ratings, release patterns, and genre distribution on Netflix. It involves data cleaning, visualization, and deriving insights from the data.")

print("\n🎯 What the Goal of the Analysis Was:")
print("The goal of this analysis was to understand Netflix's movie content strategy by identifying the most common ratings, peak release periods, and popular genres among the movies available on the platform.")

print("\n🔍 Why I Chose the Dataset:")
print("I chose the Netflix Movies dataset because Netflix is one of the largest streaming platforms globally, and analyzing its movie offerings can provide valuable insights into audience preferences, content trends, and entertainment industry shifts.")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Enhancements for visual style
# %matplotlib inline
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Load dataset from Excel
netflix_df = pd.read_excel('netflix_clean.xlsx')

# Show top rows and data summary
netflix_df.head()
# Out:
# 📚 What the Project is About:
# This project analyzes the Netflix Movies dataset to explore trends in movie ratings, release patterns, and genre distribution on Netflix. It involves data cleaning, visualization, and deriving insights from the data.
#
# 🎯 What the Goal of the Analysis Was:
# The goal of this analysis was to understand Netflix's movie content strategy by identifying the most common ratings, peak release periods, and popular genres among the movies available on the platform.
#
# 🔍 Why I Chose the Dataset:
# I chose the Netflix Movies dataset because Netflix is one of the largest streaming platforms globally, and analyzing its movie offerings can provide valuable insights into audience preferences, content trends, and entertainment industry shifts.
#   show_id     Type                Title Director  \
# 0   s8424  TV Show  The Minimighty Kids      NaN
# 1   s7522  TV Show            Mr. Young      NaN
# 2   s7343  TV Show            Lost Girl      NaN
# ...

# %%
df.info()
display(df.describe(include='all'))
display(df.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   show_id            8807 non-null   object
#  1   Type               8807 non-null   object
#  2   Title              8807 non-null   object
#  3   Director           6173 non-null   object
#  4   Cast               7982 non-null   object
#  5   Country            7976 non-null   object
#  6   Date_added         8797 non-null   object
#  7   Release_year       8807 non-null   int64
#  8   Rating             8803 non-null   object
#  9   Duration           8804 non-null   object
#  10  Listed_in          8807 non-null   object
#  11  Description        8807 non-null   object
#  12  Rating evaluation  8807 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 894.6+ KB
#        show_id   Type    Title       Director                Cast  \
# ...

# %%
content_type_counts = df['Type'].value_counts()
print(content_type_counts)
# Out:
# Type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

content_type_counts = df['Type'].value_counts()

plt.figure(figsize=(8, 6))
content_type_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Distribution of Movies and TV Shows on Netflix')
plt.xlabel('Content Type')
plt.ylabel('Number of Titles')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df['Release_year'] = df['Release_year'].astype(int)
df['Release_year'].value_counts().sort_index().plot(kind='line', figsize=(12,6), color='green')
plt.title("Netflix Content Over the Years")
plt.xlabel("Year")
plt.ylabel("Number of Releases")
plt.show()

# %%
genre_series = df['Listed_in'].dropna().apply(lambda x: x.split(', '))
genre_list = sum(genre_series.tolist(), [])
genre_counts = Counter(genre_list)

top_genres = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count']).sort_values(by='Count', ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(data=top_genres, x='Count', y='Genre', palette='magma')
plt.title("Top 10 Genres on Netflix")
plt.xlabel("Number of Titles")
plt.ylabel("Genre")
plt.show()

# %%
# Reuse exploded dataset
df_year_country = df_exploded.copy()

# Group by year and country
yearly_country = df_year_country.groupby(['Release_year', 'Country']).size().reset_index(name='Count')

# Filter only top 5 countries for a cleaner line chart
top_5 = top_10_countries['Country'].tolist()[:5]
yearly_country = yearly_country[yearly_country['Country'].isin(top_5)]

# Plot
plt.figure(figsize=(12,7))
sns.lineplot(data=yearly_country, x='Release_year', y='Count', hue='Country', palette='Set1')
plt.title("Content Releases Over Time by Country (Top 5)")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Ensure Date_added is in datetime format
df['Date_added'] = pd.to_datetime(df['Date_added'], errors='coerce')

# Extract month
df['Month_added'] = df['Date_added'].dt.month_name()

# Group and plot
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

monthly_adds = df['Month_added'].value_counts().reindex(month_order).dropna()

plt.figure(figsize=(12,6))
sns.barplot(x=monthly_adds.index, y=monthly_adds.values, palette='cubehelix')
plt.xticks(rotation=45)
plt.title("Content Added to Netflix by Month")
plt.xlabel("Month")
plt.ylabel("Number of Titles")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Option 1: Specify the correct path to your existing CSV file
# df = pd.read_csv('correct_path_to_your_file.csv')

# Option 2: Create a sample DataFrame for demonstration
# This is useful if you don't have a CSV file ready
df = pd.DataFrame({
    'director': ['Christopher Nolan', 'Steven Spielberg', 'Christopher Nolan', 
                 'Quentin Tarantino', 'Martin Scorsese', 'Steven Spielberg',
                 'Quentin Tarantino', 'Christopher Nolan', 'Martin Scorsese',
                 'Steven Spielberg', 'James Cameron', 'James Cameron']
})

# Now you can use df
top_directors = df['director'].dropna().value_counts().head(10)

plt.figure(figsize=(8,5))
top_directors.plot(kind='barh', color='mediumseagreen')
plt.title('Top 10 Directors')
plt.xlabel('Number of Titles')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
from collections import Counter  # Import the Counter class from collections module

country_data = netflix_df['Country'].dropna().apply(lambda x: x.split(', '))
all_countries = []
for countries in country_data:
    all_countries.extend(countries)

country_count = Counter(all_countries)
top_10_countries = pd.DataFrame(country_count.items(), columns=['Country', 'Count']).sort_values(by='Count', ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(data=top_10_countries, x='Count', y='Country', palette='Blues_d')
plt.title('Top 10 Countries with Most Netflix Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=netflix_df, y='Rating', order=netflix_df['Rating'].value_counts().index, palette='coolwarm')
plt.title("Distribution of Ratings")
plt.xlabel("Number of Titles")
plt.ylabel("Rating")
plt.show()
